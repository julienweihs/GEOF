# %% [markdown]
# ## Introduction to programming in Python
#
# _____________________
# *This is a translated version of Part 1 of the intro course to programming in Python written for **Ekte Data** ("Real Data"). Take a look at our [GitHub](https://github.com/irendundas/EkteData/tree/main) for more exercises for working with real data in Python.*
#
# *-- Vår Dundas, 2023*
#
# ___________________________
# Remember:
# - `Shift+Enter` to run a cell and move down to the next cell,
# - `Ctrl+Enter` to run a cell and stay in the same cell,
# - the text cells (like this one) are formatted with these same commands, and
# - to run the cells in chronological order.

# %% [markdown]
# ### Part 1: Numbers and variables
# We start with making a variable called `x`.

# %%
x=3

# %% [markdown]
# As soon as you write `something=something else` you have a new variable. To see the content of the variable you've created, you write the name of the variable:

# %%
x
# Out:
# 3

# %% [markdown]
# If you want to print some more information you can write a print statement to describe the variable:

# %%
print('The variable x =',x)
# Out:
# The variable x = 3

# %% [markdown]
# Make a new variable `y`:

# %%
y=5

# %% [markdown]
# To print out both these variables, write:

# %%
x, y
# Out:
# (3, 5)

# %% [markdown]
# Or:

# %%
print(x)
y
# Out:
# 3
# 5

# %% [markdown]
# It's just the last line in a cell that is printed out automatically. If you write, e.g., `x` and `y` on separate lines as below, only the value of`y` is printed.

# %%
x
y
# Out:
# 5

# %% [markdown]
# #### Mathematical operations with your variables
#
# Since the variables `x` and `y` are on the same format they can be added and stored as a new variable called e.g., `result`.

# %%
result=x+y

# %%
result
# Out:
# 8

# %%
print(x+y) # Add x and y
print(x*y) # Or multiply them
print(x-y) # Or subtract them
print(x/y) # Or divide them
# Out:
# 8
# 15
# -2
# 0.6

# %% [markdown]
# However, usually you won't work with single numbers. Usually you work with lists or matrixes (arrays) of values, e.g., like below:

# %%
z=[1,2,3,4,5,6] # Make the variable z
z               # Print the content of z
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# The list `z` is on Pythons default format for lists. Such lists are ok when storing some sorts of informaiton such as indices (we'll come back to this later in this exercise), labels for figures, etc. However, we do not want to store actual data in this format. The reason is that mathematical vector rules to not apply for these lists.
#
# If we, e.g., multiply `z` with 3, you would expect that all the values of `z` gets multiplied with 3, but this is not what happens:

# %%
x*z
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# What happens is that 3 versions of `z` is stacked after each other. Due to this we avoid lists, and rather work with `numpy.array`.
#
#
# ### Part 2: Numpy

# %% [markdown]
# An **array** is the same as a **matrix**. [Numpy](https://numpy.org/) is a library for working with arrays - which is exactly what we need when working with a real dataset!
#
# We have to import the Numpy library to use its functions:

# %%
import numpy as np # for mathematical operations etc

# %% [markdown]
# With Numpy you get access to lots of useful functions. You use them like this: `np.name_of_function(var)`. For instance, to take the mean of `z`, you write `np.mean(z)`. We get back to functions a bit later.

# %%
np.mean(z)
# Out:
# 3.5

# %% [markdown]
# In `numpy` you can define a vector (1D array) like this:

# %%
arr1=np.array([1,2,3,4,5,6])
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# Since we now have an array and not a list normal mathematical rules work! So if we now try to multiply `arr1` with 3, we get the expected result:

# %%
arr1*3
# Out:
# array([ 3,  6,  9, 12, 15, 18])

# %% [markdown]
# **Addition**: you can add two arrays when they have the same length. If you try to add arrays with different lengths you'll get an error message.
#
# Make two new arrays to check this:

# %%
arr2=np.array([5,3,5,2,4,6])
arr3=np.array([5,2,4,6])

# %%
print('arr1+arr2:',arr1+arr2)
# Out:
# arr1+arr2: [ 6  5  8  6  9 12]

# %%
print('arr1+arr3:',arr1+arr3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Julien-Pooya/Documents/GitHub/GEOF_UiB/Jupyter/Part1_Intro_to_programing_in_python.ipynb Cell 36 line 1
# ----> <a href='vscode-notebook-cell:/Users/Julien-Pooya/Documents/GitHub/GEOF_UiB/Jupyter/Part1_Intro_to_programing_in_python.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> print('arr1+arr3:',arr1+arr3)
#
# ValueError: operands could not be broadcast together with shapes (6,) (4,)

# %% [markdown]
# #### array.shape and len(array)
# Two very useful tools when working with arrays is `array.shape` and `len(array)`. With `shape` you check the dimensions of your variable, and with `len` you check the length.

# %%
print(len(z)) # the list `z` is len(z)=6 elements long
print(z)
# Out:
# 6
# [1, 2, 3, 4, 5, 6]

# %%
arr1.shape # The array arr1 just has six rows, so arr1 is a vector
# Out:
# (6,)

# %% [markdown]
# #### 2 dimensjoner
# Very often you'll want to work with data with more than one dimension, for instance if you have a spatial data set. `np.array()` works for this as well. Later on we'll work with a dataset separated into years with one column for each month, then you have two dimensions: the years, and the 12 months.
#
# `arr4` is an example of a 2D array:

# %%
arr4=np.array([[1,2,3],[3,4,5]])
arr4
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
arr4.shape # arr4 has 2 rows and 3 columns
# Out:
# (2, 3)

# %% [markdown]
# This illustrates an important aspect of Python programming:
# ### Rows and Columns
#
# In python the **rows** always come first, and then the **columns**. When `shape` in the array `arr4` is `(2, 3)` this means that `arr4` has **2 rows** and **3 columns**. This is important for indexing which we'll come to in section 3 of this notebook.
#
# Think **R**ace **C**ar: **R**ows then **C**olumns.

# %% [markdown]
# ## Exercise 1:
# - Make three new variables, x, y, and z. When you make these variables the variables with the same names above are overwritten. Let x and y be integers and z a 1D-array.
# - Make a fourth variable `x+y`. Print the result.
# - Make a fifth variable that equals `x+y` multiplied with `z`.
# - Make a 2D-array with 2 rows and 3 columns. Multiply this with arr4.
# - Make an array with 4 rows and 2 columns. Check that the dimensions are correct with `.shape`.
#
# Note: To make new cells to do these exercises press `Esc` and then either `a` for a new code cell above or `b` for a new code cell below. Press `Esc+m` to turn a code cell into a markdown cell if you want to take notes.

# %% [markdown]
# ## Part 3: Indexing
#
# An **index** describes which part of an array you want to look at or use in estimations.
#
# Here are a few useful rules to remember about indices in Python:
# - Use brackets `[]` around indices.
# - The first index is 0. If you have a list `x=[5, 12, 4, 7, 3, 0]`, then `x[0]=5`.
# - To get just the first three elements in `x`, write `x[:3]`.
# - To get just the last two elements in `x`, write `x[4:]` or better `x[-2:]`.
# - The last index is not included in the output! If you write `x[2:5]` you choose elements 2 until but NOT including element 5 `x[2:5]=[4, 7, 3]`.
#
# We use the variables from the previous section, `arr1` which is 1D and `arr4` which is 2D as examples below.
#
# ### 1D-indexing
#
# Make a 1D-array

# %%
arr1=np.array([5, 12, 4, 7, 3, 0])

# %% [markdown]
# To find the values from index 3 to the end of the array:

# %%
arr1[3:]
# Out:
# array([7, 3, 0])

# %% [markdown]
# To find the first two values:

# %%
arr1[:2]
# Out:
# array([ 5, 12])

# %% [markdown]
# If you want the
# - first element in `arr1`
# - the last element in `arr1`
# - the first to and including the second element in `arr1`
# - the last three elements in `arr1`
#
# you can write as follows:

# %%
print('first element in arr1:', arr1[0])
print('last element in arr1:', arr1[5])
print('first to and including the second element in arr1:', arr1[:2])
print('the three last elements in arr1:', arr1[3:])
# Out:
# first element in arr1: 5
# last element in arr1: 0
# first to and including the second element in arr1: [ 5 12]
# the three last elements in arr1: [7 3 0]

# %% [markdown]
# **Counting backwards**
# As briefly mentioned, you can start counting indices at the end of the array and count backwards. This is very practical when working with large arrays and if you want to extract elements at the end of the array.
#
# The last element has index `-1`, the second to last is `-2`, etc.
#
# This means that if you want the last element of `arr1` you have two options:

# %%
print(arr1)

print(arr1[5]) 
print(arr1[-1])
# Out:
# [ 5 12  4  7  3  0]
# 0
# 0

# %% [markdown]
# If `arr1` was e.g.,  135423 elemts long it's a lot tidier to write `arr1[-1]` than `arr1[135422]`. With `arr1[-1]` you realize at once that the last element is extracted. With `arr1[135422]` you have to already know that `arr1` has 135423 elemts to realize that the last element is extracted.
#
# To select the last three elements of `arr1` write:

# %%
arr1[-3:]
# Out:
# array([7, 3, 0])

# %% [markdown]
# ### Exercise 2:
# - Make a Numpy-array `x` with 5 elements.
# - Find the first element of `x`.
# - Find element two to and including 4 in `x`.
# - Find the last element of `x` with two different methods.
# - Find the last four elements of `x` by counting backwards.

# %% [markdown]
# ### 2D-indeksering
#
# Recall:
# *In python the **rows** always come first, and then the **columns**. When `shape` in the array `arr4` is `(2, 3)` this means that `arr4` has **2 rows** and **3 columns**. This is important for indexing which we'll come to in section 3 of this notebook. Think **R**ace **C**ar: **R**ows then **C**olumns.*
#
# Continue working with the 2D-array `arr4`:

# %%
arr4
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %% [markdown]
# If you want the element on the first row in the first column of `arr4`, write:

# %%
arr4[0,0]
# Out:
# 1

# %% [markdown]
# To extract the elements on
# - first row, second column,
# - first row, second column and third column,
# - last row and the two last columns,
# - both rows and the two first columns, write

# %%
print('1)', arr4[0,1])
print('2)', arr4[0,1:])
print('3)', arr4[1,-2:])
print('4)', arr4[:,:2])
# Out:
# 1) 2
# 2) [2 3]
# 3) [4 5]
# 4) [[1 2]
#  [3 4]]

# %% [markdown]
# ### Exercise 3:
# - Make a new array `y` with three rows and 4 columns.
# - Find the elements on the first row and the three first columns.
# - Find the elements on the last two rows and the last column using two different methods.

# %% [markdown]
# ### Part 4: Load a real data set!
#
# In this section we load a dataset over yearly temperature in Bergen, Norway since 1861. We use a function called `loadData` which is defined in the file "EkteDataFunk.py" in the folder "Functions". This function is found [here](https://github.com/julienweihs/GEOF/tree/main/Python) and you need it locally on your computer. The functions downloads the file from [here](https://github.com/irendundas/EkteData/tree/main/data), so you don't need the data file locally on your computer.
#
# To get the cell below to work you have to change the **path** (which is now W:\Work\Documents\GEOF_UiB\Python since this is where I have the function on my computer) to where you have this function on your computer. Remeber that the dashes, `/`, have to be correct! If you use Windows, they're automatically the wrong way, i.e., `\`. Then you can either change them to `/`, use double dashes `\\`, or put an `r` in front of you path, like I've done below.

# %%
import sys
# !!! Replace W:\Work\Documents\GEOF_UiB\Python with the path 
# on YOUR PC !!! One clean way to do this is to locate your EkteDataFunk.py-file, right-click it, and use the 'Copy Path' command
sys.path.append(r"W:\Work\Documents\GEOF_UiB\Python")

from EkteDataFunk import loadData # for loading of files

# %%
file='TempBergenYearlyNonan.txt' # The name of the file we are going to load
data = loadData(file, rydd='N')  # Use the loadData function to load the file

data   # This prints out all the values in "data"
# Out:
# array([[1861.        ,    8.33636364],
#        [1862.        ,    7.71666667],
#        [1863.        ,    7.75833333],
#        [1864.        ,    6.86666667],
#        [1865.        ,    7.225     ],
#        [1866.        ,    7.41666667],
#        [1867.        ,    6.55      ],
#        [1868.        ,    7.975     ],
#        [1869.        ,    6.45      ],
#        [1870.        ,    6.575     ],
#        [1871.        ,    7.64545455],
#        [1872.        ,    8.275     ],
#        [1873.        ,    7.83333333],
#        [1874.        ,    7.175     ],
#        [1875.        ,    7.01666667],
#        [1876.        ,    6.78333333],
#        [1877.        ,    6.55      ],
#        [1878.        ,    7.06666667],
#        [1879.        ,    6.69166667],
#        [1880.        ,    7.53333333],
#        [1881.        ,    6.36666667],
#        [1882.        ,    7.9       ],
#        [1883.        ,    7.6       ],
#        [1884.        ,    8.20833333],
# ...

# %% [markdown]
# The variable `data` have the exact same format as `arr4` that we worked with above. The only difference is that `data` is longer: it has 160 rows (for 160 years of temperature measurements) and two columns (year and temperature), while `arr4` had two rows and thre columns.

# %%
print(arr4.shape)
data.shape
# Out:
# (2, 3)
# (160, 2)

# %% [markdown]
# Now we can use what we have learned about variables and indexing to create two new variables: one over the years, i.e. all the rows in the first column, and one over the temperature, i.e. all the rows in the second column.

# %%
tid=data[:,0] # all rows ":" and first column "0"
tid # print out the variable
# Out:
# array([1861., 1862., 1863., 1864., 1865., 1866., 1867., 1868., 1869.,
#        1870., 1871., 1872., 1873., 1874., 1875., 1876., 1877., 1878.,
#        1879., 1880., 1881., 1882., 1883., 1884., 1885., 1886., 1887.,
#        1888., 1889., 1890., 1891., 1892., 1893., 1894., 1895., 1896.,
#        1897., 1898., 1899., 1900., 1901., 1902., 1903., 1904., 1905.,
#        1906., 1907., 1908., 1909., 1910., 1911., 1912., 1913., 1914.,
#        1915., 1916., 1917., 1918., 1919., 1920., 1921., 1922., 1923.,
#        1924., 1925., 1926., 1927., 1928., 1929., 1930., 1931., 1932.,
#        1933., 1934., 1935., 1936., 1937., 1938., 1939., 1940., 1941.,
#        1942., 1943., 1944., 1945., 1946., 1947., 1948., 1949., 1950.,
#        1951., 1952., 1953., 1954., 1955., 1956., 1957., 1958., 1959.,
#        1960., 1961., 1962., 1963., 1964., 1965., 1966., 1967., 1968.,
#        1969., 1970., 1971., 1972., 1973., 1974., 1975., 1976., 1977.,
# ...

# %%
temp=data[:,1] # all rows ":" and second column "0"
temp
# Out:
# array([8.33636364, 7.71666667, 7.75833333, 6.86666667, 7.225     ,
#        7.41666667, 6.55      , 7.975     , 6.45      , 6.575     ,
#        7.64545455, 8.275     , 7.83333333, 7.175     , 7.01666667,
#        6.78333333, 6.55      , 7.06666667, 6.69166667, 7.53333333,
#        6.36666667, 7.9       , 7.6       , 8.20833333, 6.70833333,
#        6.83333333, 6.99166667, 6.55      , 7.925     , 7.78333333,
#        7.73333333, 6.26666667, 7.49166667, 8.33333333, 6.75833333,
#        7.40833333, 7.25      , 7.15      , 6.96666667, 6.70833333,
#        7.675     , 6.40833333, 7.18333333, 6.89166667, 7.08333333,
#        7.38333333, 6.95      , 7.575     , 6.53333333, 7.79166667,
#        7.56666667, 7.59166667, 7.81666667, 7.93333333, 5.95833333,
#        7.1       , 6.60833333, 7.5       , 6.125     , 7.68333333,
#        7.2       , 6.425     , 6.46666667, 7.28333333, 7.85833333,
#        7.73333333, 7.19166667, 7.14166667, 7.04166667, 8.50833333,
# ...

# %% [markdown]
# ## Part 5: use functions from `Numpy`
#
# To get an overview of the annual temperature in Bergen since 1861, it can be useful to look at values such as average, maximum value, minimum value and standard deviation. `Numpy` has built-in functions for this:

# %%
np.mean(temp)
# Out:
# 7.6283759469696975

# %%
print('Average temperature: ', np.mean(temp), '\u2103')
print('Maximum temperature: ', np.max(temp), '\u2103')
print('Minimum temperature: ', np.min(temp), '\u2103')
print('Standard deviation: ', np.std(temp), '\u2103')
# Out:
# Average temperature:  7.6283759469696975 ℃
# Maximum temperature:  9.908333333333333 ℃
# Minimum temperature:  5.958333333333332 ℃
# Standard deviation:  0.7350653423327863 ℃

# %% [markdown]
# The new variables `temp` and `time` can be indexed in the same way as in the examples above. In order to calculate the average e.g. of the first 10 years, we do as follows:

# %%
np.mean(temp[:10])
# Out:
# 7.286969696969697

# %% [markdown]
# If we are to calculate the average over the last ten years, we do this as follows:

# %%
np.mean(temp[-10:])
# Out:
# 8.740833333333333

# %% [markdown]
# As a test that this is actually the average of the **ten** first years, you can check the length of `temp[:10]`:

# %%
temp[:10].shape
# Out:
# (10,)

# %% [markdown]
# ## Exercise 4:
# - Find the average temperature and standard deviation for the first 50 years.
# - Find the average temperature and standard deviation for the last 50 years.

# %% [markdown]
# Although values such as averages are useful for describing temperature, it is difficult to get a proper impression of how the annual temperature since 1861 has varied just by looking at values such as this. The best is to look at a figure of the time series.

# %% [markdown]
# ## Part 6: Create a figure
# Just as we need the `Numpy` library to create matrices and perform mathematical operations such as finding averages, we need a library to create figures. We use `matplotlib`:

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tid, temp)

# %% [markdown]
# The figure above reflects what we found by calculating averages: the first 50 years were colder than the last 50 years, the maximum temperature was almost 10 degrees, the minimum temperature was about 6 degrees, and the values mostly stayed below one degree away from the average. But we get much more information additionally, such as *when* it was hottest and coldest, and that the temperature has not increased steadily.
#
# Figures should always be interpretable without a lot of accompanying text - yet we must add titles, names of the axes etc.

# %%
plt.plot(tid, temp)
plt.title('Average annual rainfall Bergen')
plt.xlabel('Year')
plt.ylabel('Temperature [\u2103]') # \u2103 is the code for "Celsius degrees"

# The line below delimits the x-axis so that there are no "whitespaces" on
# either ends, as in the figure above
plt.xlim(tid[0], tid[-1])

# The line below just means that information about the previous line is not printed.
# You can comment it out and rerun this cell to see
plt.show()

# %% [markdown]
# You can create a figure that only shows part of the data set by indexing it in the same way as we have done previously. In order to e.g. only plot the last 100 years, you do it like this:

# %%
plt.plot(tid[-100:], temp[-100:])
plt.title('Average annual rainfall Bergen')
plt.xlabel('Year')
plt.ylabel('Temperature [\u2103]')
plt.xlim(tid[-100], tid[-1]) 
plt.show()

# %% [markdown]
# You can also plot several lines in the same figure. For this, you just add a line with `plt.plot()` for each new variable you want to plot. The plot lines are then created in the order in which they are written.
#
# A small note about lines as we plot the red line for the average value in the cell below: We can write `plt.hlines()` because `plt.hlines()` is a built-in function of `Matplotlib` for plotting horizontal lines. Similarly, there is `plt.vlines()` for vertical lines. We will return to how to find out that such functions exist and how to use them later when we look at documentation. To give a hint: I would just google "plot horizontal line matplotlib" if I didn't remember if there was a function for this or how it worked!

# %%
plt.plot(tid, temp) # Plot hele tidsserien
plt.plot(tid[-100:], temp[-100:]) # Plot kun de siste 100 årene

# Plot gjennomsnittet som en rød linje. 
plt.hlines(np.mean(temp), tid[0], tid[-1], color='red') 
plt.title('Average annual precipitation Bergen')
plt.xlabel('Year')
plt.ylabel('Temperature [\u2103]')
plt.xlim(tid[0], tid[-1]) 
plt.show()

# %% [markdown]
# The orange line now represents the last 100 years and is plotted on top of the blue line showing the entire time series. The red line shows the average of the entire time series. To create this, we use the function `plt.hlines()` which stands for "horizontal lines". You give the function 1) the y-value the line should cross, 2) the start value of the line, and 3) the end value of the line along the x-axis. In the example above, this is 1) `np.mean(temp)`, 2) `time[0]`, and 3) `time[-1]`.

# %% [markdown]
# ## Exercise 5:
# Create a figure that shows the following:
# - the entire time series
# - the first 75 years
# - the average of the entire time series
# - the average of the first 75 years.
#
# Then create a new figure that shows:
# - the years from the 50th year until the 50th-to-last year
# - the average for this period
# - the average plus and minus the standard deviation for this period.

# %%
plt.plot(tid, temp)
plt.plot(tid[:75], temp[:75])
plt.hlines(np.mean(temp), tid[0], tid[-1], color='red')
plt.hlines(np.mean(temp[:75]), tid[0], tid[75], color='red')
plt.title('Average annual rainfall Bergen')
plt.xlabel('Year')
plt.ylabel('Temperature [\u2103]')
plt.xlim(tid[0], tid[-1]) 
plt.show()

# %%
plt.plot(tid[50:-50], temp[50:-50])
plt.hlines(np.mean(temp[50:-50]), tid[50], tid[-50], color='red')
plt.hlines(np.mean(temp[50:-50])-np.std(temp[50:-50]), tid[50], tid[-50], color='green')
plt.hlines(np.mean(temp[50:-50])+np.std(temp[50:-50]), tid[50], tid[-50], color='green')
plt.title('Average annual rainfall Bergen')
plt.xlabel('Year')
plt.ylabel('Temperature [\u2103]')
plt.xlim(tid[50], tid[-50]) 
plt.show()
